# %% [markdown]
# ## Import libraries and setup

# %%
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# DWave Credentials
dwave_solver = os.getenv('DWAVE_API_SOLVER')
api_key = os.getenv('DWAVE_API_TOKEN')

from dwave.system.samplers import DWaveSampler
from dwave.system.composites import EmbeddingComposite

import dwave_networkx as dnx

### Use NetworkX graphic package to create a graph
import networkx as nx

# Select a D-Wave system and handle mapping from problem graph to sampler graph
sampler = EmbeddingComposite(DWaveSampler(solver=dwave_solver, token=api_key))

# %% [markdown]
# ## Create Bipartite Graph

# %%
from networkx.algorithms import bipartite

B = nx.Graph()

# Add nodes with the node attribute "bipartite"
B.add_nodes_from(['A', 'B', 'C'], bipartite=0)
B.add_nodes_from(['F', 'G', 'H'], bipartite=1)

# Add edges only between nodes of opposite node sets
B.add_edges_from([('A', 'F', {'assigned': 0}), ('A', 'G', {'assigned': 0}), 
                  ('B', 'F', {'assigned': 1}), ('B', 'H', {'assigned': 0}), 
                  ('C', 'G', {'assigned': 1})])

# %% [markdown]
# ## Create Distance Matrix

# %%
D = []
dists = dict(nx.all_pairs_dijkstra_path_length(B))

for node, d in dists.items():
    D.append(list(d.values()))

# %% [markdown]
# ##

# %% [markdown]
# ## Draw Bipartite Graph

# %%
X, Y = bipartite.sets(B)
pos = dict()
pos.update( (n, (1, i)) for i, n in enumerate(X) ) # put nodes from X at x=1
pos.update( (n, (2, i)) for i, n in enumerate(Y) ) # put nodes from Y at x=2
nx.draw_networkx(B, pos=pos)
plt.show()
# Out:
# /Users/angadkalra/Projects/dwave_ocean/lib/python3.5/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
